# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import json
import pandas as pd
from pprint import pprint
import openweathermapy.core as owm
import seaborn as sns

# %%
import numpy as np

np_lat = np.arange(-90,90,10)
np_lng = np.arange(-180,180,18)
# coordinates = (np_lat,np_lng) #Better keeping lat/lng in separate columns

import random

rnd_lat = random.choice(np_lat)
rnd_lng = random.choice(np_lng)
# rnd_coordinates = random.choice(coordinates) #Better keeping lat/lng in separate columns

from citipy import citipy

weather_df = pd.DataFrame()
weather_df['rnd_lat']=""
weather_df['rnd_lng']=""

for x in np_lat:
    for y in np_lng:
        x_values = list(np.arange(-90,90,0.01))
        y_values = list(np.arange(-180,180,0.01))
        lats = random.sample(x_values,17999) #why 17999 instead of 500? Because of duplicates..
        lons = random.sample(y_values,17999) #..stemming from the geocoords from citipy
                                            #and that's the maximum number of samples I can input
                                            #given the latitude parameters (180/0.01 = 18000)
                                            #Also I believe a larger sampling size to be better to
                                            #increase the random distribution of values.
        
weather_df = weather_df.append(pd.DataFrame.from_dict({"rnd_lat":lats,
                                       "rnd_lng":lons}))

weather_df = weather_df.reset_index(drop=True)



weather_df['city']=""
weather_df['country_code']=""

for index,row in weather_df.iterrows():
        weather_df_city = citipy.nearest_city(row["rnd_lat"], row["rnd_lng"])
        weather_df.set_value(index,"city",weather_df_city.city_name)
        weather_df.set_value(index,"country_code",weather_df_city.country_code)
        
weather_df=weather_df.drop(['rnd_lat', 'rnd_lng'],axis=1) #geo coord don't correspond to cities

weather_df=weather_df.drop_duplicates() #hmmm, some coords might yield similar cities....
print("Sampling size (from n = 17,999) after dumping duplicates: n=" + str(len(weather_df)))

weather_df = weather_df.sample(800) #resample so that n=800 (why? because some cities will may lack
                                    # data for certain attributes, so we'll re-sample once data has
                                    # dropped any rows with NULL values for any attributes)
weather_df = weather_df.reset_index(drop=True) #Remove index pre-resampling

print(weather_df.head())

print("Confirm n = 800: " + str(weather_df.shape))
# Out:
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:42: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:43: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Sampling size (from n = 17,999) after dumping duplicates: n=3333
#           city country_code
# 0       osijek           hr
# 1         daru           pg
# 2  morgan city           us
# 3      montijo           pa
# 4       mpanda           tz
# Confirm n = 800: (800, 2)

# %%
from config2 import api_key 

    # Set parameters to pass in query URL
units = "metric" 
params = {
    "appid": api_key,
    "units": "metric",
}

    # Set counter for request iteration for each city
counter = 0

    # Set Request Loop
for index, row in weather_df.iterrows():
    params["q"] =f'{row["city"]},{row["country_code"]}' #Set location params: city, country_code
    target_url = 'http://api.openweathermap.org/data/2.5/weather?' #i.e. OWM's base API url

    counter += 1 # add to the index count for each iterations
#     print("Now retrieving city # " + str(counter)) #making sure the counter iteration is working
    
    city_owm = requests.get(target_url, params=params)
    print("ID:"+ str(counter) + " " + "OWM info for " + str( params["q"]))
    print(city_owm.url) #making sure the request iterations are working for each location.
    
    city_owm  = city_owm.json()
    
    #Pull attributes of interest from OWM request
    weather_df.set_value(index,"Latitude",city_owm.get("coord",{}).get("lat"))
    weather_df.set_value(index,"Longitude",city_owm.get("coord",{}).get("lon"))
    weather_df.set_value(index,"Temperature",city_owm.get("main",{}).get("temp_max"))
    weather_df.set_value(index,"Wind_speed",city_owm.get("wind",{}).get("speed"))
    weather_df.set_value(index,"Humidity",city_owm.get("main",{}).get("humidity"))
    weather_df.set_value(index,"Cloudiness",city_owm.get("clouds",{}).get("all"))
# Out:
# ID:1 OWM info for szczytno,pl
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=szczytno%2Cpl
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:28: FutureWarning:
#
# set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:29: FutureWarning:
#
# set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:30: FutureWarning:
#
# set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:31: FutureWarning:
#
# set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:32: FutureWarning:
#
# set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:33: FutureWarning:
#
# set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# ID:2 OWM info for aljezur,pt
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=aljezur%2Cpt
# ID:3 OWM info for camacupa,ao
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=camacupa%2Cao
# ID:4 OWM info for ronne,dk
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ronne%2Cdk
# ID:5 OWM info for katherine,au
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=katherine%2Cau
# ID:6 OWM info for akhtanizovskaya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=akhtanizovskaya%2Cru
# ID:7 OWM info for eresos,gr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=eresos%2Cgr
# ID:8 OWM info for comodoro rivadavia,ar
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=comodoro+rivadavia%2Car
# ID:9 OWM info for sao joao da barra,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=sao+joao+da+barra%2Cbr
# ID:10 OWM info for loreto,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=loreto%2Cmx
# ID:11 OWM info for la palma,pa
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=la+palma%2Cpa
# ID:12 OWM info for lagoa,pt
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=lagoa%2Cpt
# ID:13 OWM info for ugoofaaru,mv
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ugoofaaru%2Cmv
# ID:14 OWM info for derzhavinsk,kz
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=derzhavinsk%2Ckz
# ID:15 OWM info for xihe,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=xihe%2Ccn
# ID:16 OWM info for lompoc,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=lompoc%2Cus
# ID:17 OWM info for souillac,mu
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=souillac%2Cmu
# ID:18 OWM info for quzhou,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=quzhou%2Ccn
# ID:19 OWM info for geraldton,ca
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=geraldton%2Cca
# ID:20 OWM info for oktyabrskoye,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=oktyabrskoye%2Cru
# ID:21 OWM info for nigde,tr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=nigde%2Ctr
# ID:22 OWM info for banda aceh,id
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=banda+aceh%2Cid
# ID:23 OWM info for maun,bw
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=maun%2Cbw
# ID:24 OWM info for pontal do parana,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q
br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=porangatu%2Cbr
# ID:120 OWM info for mosnita noua,ro
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=mosnita+noua%2Cro
# ID:121 OWM info for burgdorf,ch
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=burgdorf%2Cch
# ID:122 OWM info for verkhoyansk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=verkhoyansk%2Cru
# ID:123 OWM info for cao bang,vn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=cao+bang%2Cvn
# ID:124 OWM info for san patricio,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=san+patricio%2Cmx
# ID:125 OWM info for belmonte,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=belmonte%2Cbr
# ID:126 OWM info for ahlat,tr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ahlat%2Ctr
# ID:127 OWM info for benoy,td
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=benoy%2Ctd
# ID:128 OWM info for grootfontein,na
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=grootfontein%2Cna
# ID:129 OWM info for snyder,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=snyder%2Cus
# ID:130 OWM info for ntoum,ga
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ntoum%2Cga
# ID:131 OWM info for taua,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=taua%2Cbr
# ID:132 OWM info for mount pleasant,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=mount+pleasant%2Cus
# ID:133 OWM info for portree,gb
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=portree%2Cgb
# ID:134 OWM info for koslan,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=koslan%2Cru
# ID:135 OWM info for havoysund,no
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=havoysund%2Cno
# ID:136 OWM info for punta alta,ar
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=punta+alta%2Car
# ID:137 OWM info for broome,au
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=broome%2Cau
# ID:138 OWM info for yarmouth,ca
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=yarmouth%2Cca
# ID:139 OWM info for sotouboua,tg
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=sotouboua%2Ctg
# ID:140 OWM info for tonstad,no
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=tonstad%2Cno
# ID:141 OWM info for saposoa,pe
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=saposoa%2Cpe
# ID:142 OWM info for roanoke rapids,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=roanoke+rapids%2Cus
# ID:143 OWM info for la peca,pe
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=la+peca%2Cpe
# ID:144 OWM info for xinpu,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=xinpu%2Ccn
# ID:145 OWM info for baijiantan,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=baijiantan%2Ccn
# ID:146 OWM info for mpanda,tz
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=mpanda%2Ctz
# ID:147 OWM info for kaabong,ug
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kaabong%2Cug
# ID:148 OWM info for pangoa,pe
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=pangoa%2Cpe
# ID:149 OWM info for ust-uda,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ust-uda%2Cru
# ID:150 OWM info for seoul,kr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=seoul%2Ckr
# ID:151 OWM info for nhulunbuy,au
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=nhulunbuy%2Cau
# ID:152 OWM info for nadbai,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=nadbai%2Cin
# ID:153 OWM info for la gomera,gt
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=la+gomera%2Cgt
# ID:154 OWM info for morgan city,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=morgan+city%2Cus
# ID:155 OWM info for contamana,pe
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=contamana%2Cpe
# ID:156 OWM info for providencia,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=providencia%2Cmx
# ID:157 OWM info for basoko,cd
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=basoko%2Ccd
# ID:158 OWM info for hobyo,so
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=hobyo%2Cso
# ID:159 OWM info for siniscola,it
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=siniscola%2Cit
# ID:160 OWM info for morro bay,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=morro+bay%2Cus
# ID:161 OWM info for marawi,sd
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=marawi%2Csd
# ID:162 OWM info for panguna,pg
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=panguna%2Cpg
# ID:163 OWM info for pokhara,np
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=pokhara%2Cnp
# ID:164 OWM info for politika,gr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=politika%2Cgr
# ID:165 OWM info for burnie,au
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=burnie%2Cau
# ID:166 OWM info for korem,et
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=korem%2Cet
# ID:167 OWM info for kabompo,zm
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kabompo%2Czm
# ID:168 OWM info for ponta delgada,pt
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=harper%2Clr
# ID:217 OWM info for areosa,pt
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=areosa%2Cpt
# ID:218 OWM info for taree,au
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=taree%2Cau
# ID:219 OWM info for tautira,pf
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=tautira%2Cpf
# ID:220 OWM info for buenos aires,cr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=buenos+aires%2Ccr
# ID:221 OWM info for mafeteng,ls
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=mafeteng%2Cls
# ID:222 OWM info for thomasville,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=thomasville%2Cus
# ID:223 OWM info for doembang nangbuat,th
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=doembang+nangbuat%2Cth
# ID:224 OWM info for agua verde,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=agua+verde%2Cmx
# ID:225 OWM info for mbandaka,cd
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=mbandaka%2Ccd
# ID:226 OWM info for kattivakkam,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kattivakkam%2Cin
# ID:227 OWM info for beitbridge,zw
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=beitbridge%2Czw
# ID:228 OWM info for iranshahr,ir
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=iranshahr%2Cir
# ID:229 OWM info for helong,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=helong%2Ccn
# ID:230 OWM info for bagdarin,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=bagdarin%2Cru
# ID:231 OWM info for igarka,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=igarka%2Cru
# ID:232 OWM info for lucea,jm
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=lucea%2Cjm
# ID:233 OWM info for bhainsdehi,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=bhainsdehi%2Cin
# ID:234 OWM info for nchelenge,zm
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=nchelenge%2Czm
# ID:235 OWM info for kuala kedah,my
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kuala+kedah%2Cmy
# ID:236 OWM info for rio do sul,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=rio+do+sul%2Cbr
# ID:237 OWM info for puerto montt,cl
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=puerto+montt%2Ccl
# ID:238 OWM info for guerrero negro,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=guerrero+negro%2Cmx
# ID:239 OWM info for zalantun,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=zalantun%2Ccn
# ID:240 OWM info for jiexiu,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=jiexiu%2Ccn
# ID:241 OWM info for buchanan,lr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=buchanan%2Clr
# ID:242 OWM info for fereydunshahr,ir
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=fereydunshahr%2Cir
# ID:243 OWM info for ingham,au
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ingham%2Cau
# ID:244 OWM info for daru,pg
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=daru%2Cpg
# ID:245 OWM info for mahalapye,bw
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=mahalapye%2Cbw
# ID:246 OWM info for shaunavon,ca
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=shaunavon%2Cca
# ID:247 OWM info for granada,ph
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=granada%2Cph
# ID:248 OWM info for nuevo progreso,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=nuevo+progreso%2Cmx
# ID:249 OWM info for kirkwood,za
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kirkwood%2Cza
# ID:250 OWM info for zaozerne,ua
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=zaozerne%2Cua
# ID:251 OWM info for jogbani,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=jogbani%2Cin
# ID:252 OWM info for staraya russa,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=staraya+russa%2Cru
# ID:253 OWM info for zvishavane,zw
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=zvishavane%2Czw
# ID:254 OWM info for concepcion del uruguay,ar
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=concepcion+del+uruguay%2Car
# ID:255 OWM info for saquena,pe
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=saquena%2Cpe
# ID:256 OWM info for zhaotong,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=zhaotong%2Ccn
# ID:257 OWM info for cukai,my
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=cukai%2Cmy
# ID:258 OWM info for batsfjord,no
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=batsfjord%2Cno
# ID:259 OWM info for kamina,cd
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kamina%2Ccd
# ID:260 OWM info for santiago del estero,ar
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=santiago+del+estero%2Car
# ID:261 OWM info for mitsamiouli,km
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=mitsamiouli%2Ckm
# ID:262 OWM info for bjornevatn,no
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=bjornevatn%2Cno
# ID:263 OWM info for mujiayingzi,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=mujiayingzi%2Ccn
# ID:264 OWM info for manacapuru,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=manacapuru%2Cbr
# ID:265 OWM info for kisaran,id
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kisaran%2Cid
# ID:266 OWM info for high level,ca
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=high+level%2Cca
# ID:267 OWM info for haines junction,ca
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=haines+junction%2Cca
# ID:268 OWM info for bocana de paiwas,ni
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=bocana+de+paiwas%2Cni
# ID:269 OWM info for srandakan,id
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=srandakan%2Cid
# ID:270 OWM info for tingi,tz
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=tingi%2Ctz
# ID:271 OWM info for yangambi,cd
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=yangambi%2Ccd
# ID:272 OWM info for coihaique,cl
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=coihaique%2Ccl
# ID:273 OWM info for gummidipundi,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=gummidipundi%2Cin
# ID:274 OWM info for oltu,tr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=oltu%2Ctr
# ID:275 OWM info for maumelle,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=maumelle%2Cus
# ID:276 OWM info for centralina,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=centralina%2Cbr
# ID:277 OWM info for georgetown,sh
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=georgetown%2Csh
# ID:278 OWM info for tifton,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=tifton%2Cus
# ID:279 OWM info for macapa,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=macapa%2Cbr
# ID:280 OWM info for creel,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=creel%2Cmx
# ID:281 OWM info for bethanien,na
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=bethanien%2Cna
# ID:282 OWM info for tonota,bw
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=tonota%2Cbw
# ID:283 OWM info for bardiyah,ly
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=bardiyah%2Cly
# ID:284 OWM info for urucui,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=urucui%2Cbr
# ID:285 OWM info for sabancuy,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=sabancuy%2Cmx
# ID:286 OWM info for amuntai,id
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=amuntai%2Cid
# ID:287 OWM info for nalus,ph
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=nalus%2Cph
# ID:288 OWM info for nikolskoye,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=nikolskoye%2Cru
# ID:289 OWM info for sungai besar,my
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=sungai+besar%2Cmy
# ID:290 OWM info for pimenta bueno,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=pimenta+bueno%2Cbr
# ID:291 OWM info for tolaga bay,nz
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=tolaga+bay%2Cnz
# ID:292 OWM info for tarko-sale,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=tarko-sale%2Cru
# ID:293 OWM info for kavaratti,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kavaratti%2Cin
# ID:294 OWM info for kenai,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kenai%2Cus
# ID:295 OWM info for genhe,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=genhe%2Ccn
# ID:296 OWM info for elburg,nl
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=elburg%2Cnl
# ID:297 OWM info for riva,it
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=riva%2Cit
# ID:298 OWM info for emerald,au
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=emerald%2Cau
# ID:299 OWM info for suruc,tr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=suruc%2Ctr
# ID:300 OWM info for molokovo,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=molokovo%2Cru
# ID:301 OWM info for colares,pt
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=colares%2Cpt
# ID:302 OWM info for iquitos,pe
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=iquitos%2Cpe
# ID:303 OWM info for canon city,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=canon+city%2Cus
# ID:304 OWM info for terme,tr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=terme%2Ctr
# ID:305 OWM info for masvingo,zw
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=masvingo%2Czw
# ID:306 OWM info for waiouru,nz
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=waiouru%2Cnz
# ID:307 OWM info for benicarlo,es
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=benicarlo%2Ces
# ID:308 OWM info for blytheville,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=blytheville%2Cus
# ID:309 OWM info for union,py
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=union%2Cpy
# ID:310 OWM info for shache,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=shache%2Ccn
# ID:311 OWM info for grieskirchen,at
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=grieskirchen%2Cat
# ID:312 OWM info for praia,cv
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=praia%2Ccv
# ID:313 OWM info for tougue,gn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=tougue%2Cgn
# ID:314 OWM info for pangody,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=pangody%2Cru
# ID:315 OWM info for cloquet,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=cloquet%2Cus
# ID:316 OWM info for bestobe,kz
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=bestobe%2Ckz
# ID:317 OWM info for yelniki,ru
# ...
# ID:393 OWM info for geraldton,au
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=geraldton%2Cau
# ID:394 OWM info for norden,de
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=norden%2Cde
# ID:395 OWM info for warrington,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=warrington%2Cus
# ID:396 OWM info for ena,jp
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ena%2Cjp
# ID:397 OWM info for xiongzhou,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=xiongzhou%2Ccn
# ID:398 OWM info for ouesso,cg
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ouesso%2Ccg
# ID:399 OWM info for neftcala,az
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=neftcala%2Caz
# ID:400 OWM info for zedelgem,be
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=zedelgem%2Cbe
# ID:401 OWM info for jumla,np
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=jumla%2Cnp
# ID:402 OWM info for cahors,fr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=cahors%2Cfr
# ID:403 OWM info for nedjo,et
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=nedjo%2Cet
# ID:404 OWM info for tremedal,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=tremedal%2Cbr
# ID:405 OWM info for ushuaia,ar
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ushuaia%2Car
# ID:406 OWM info for tshikapa,cd
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=tshikapa%2Ccd
# ID:407 OWM info for hauknes,no
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=hauknes%2Cno
# ID:408 OWM info for mawlamyine,mm
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=mawlamyine%2Cmm
# ID:409 OWM info for leticia,co
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=leticia%2Cco
# ID:410 OWM info for grenville,gd
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=grenville%2Cgd
# ID:411 OWM info for lure,fr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=lure%2Cfr
# ID:412 OWM info for aksay,kz
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=aksay%2Ckz
# ID:413 OWM info for cockburn town,tc
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=cockburn+town%2Ctc
# ID:414 OWM info for anloga,gh
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=anloga%2Cgh
# ID:415 OWM info for bad wildungen,de
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=bad+wildungen%2Cde
# ID:416 OWM info for frontera,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=frontera%2Cmx
# ID:417 OWM info for nemuro,jp
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=nemuro%2Cjp
# ID:418 OWM info for fez,ma
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=fez%2Cma
# ID:419 OWM info for cacahuatepec,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=cacahuatepec%2Cmx
# ID:420 OWM info for ust-barguzin,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ust-barguzin%2Cru
# ID:421 OWM info for westport,ie
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=westport%2Cie
# ID:422 OWM info for wroclaw,pl
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=wroclaw%2Cpl
# ID:423 OWM info for jackson,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=jackson%2Cus
# ID:424 OWM info for mbuji-mayi,cd
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=mbuji-mayi%2Ccd
# ID:425 OWM info for waingapu,id
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=waingapu%2Cid
# ID:426 OWM info for murfreesboro,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=murfreesboro%2Cus
# ID:427 OWM info for itarema,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=itarema%2Cbr
# ID:428 OWM info for nabinagar,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=nabinagar%2Cin
# ID:429 OWM info for karanja,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=karanja%2Cin
# ID:430 OWM info for hualmay,pe
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=hualmay%2Cpe
# ID:431 OWM info for san rafael,ar
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=san+rafael%2Car
# ID:432 OWM info for nantucket,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=nantucket%2Cus
# ID:433 OWM info for ryotsu,jp
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=
ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=talaya%2Cru
# ID:483 OWM info for alvaraes,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=alvaraes%2Cbr
# ID:484 OWM info for khoy,ir
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=khoy%2Cir
# ID:485 OWM info for skibbereen,ie
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=skibbereen%2Cie
# ID:486 OWM info for dauriya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=dauriya%2Cru
# ID:487 OWM info for karimnagar,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=karimnagar%2Cin
# ID:488 OWM info for shakhtinsk,kz
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=shakhtinsk%2Ckz
# ID:489 OWM info for sunndalsora,no
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=sunndalsora%2Cno
# ID:490 OWM info for katakwi,ug
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=katakwi%2Cug
# ID:491 OWM info for nipawin,ca
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=nipawin%2Cca
# ID:492 OWM info for mildura,au
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=mildura%2Cau
# ID:493 OWM info for noumea,nc
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=noumea%2Cnc
# ID:494 OWM info for latung,ph
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=latung%2Cph
# ID:495 OWM info for akdepe,tm
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=akdepe%2Ctm
# ID:496 OWM info for dhandhuka,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=dhandhuka%2Cin
# ID:497 OWM info for porto walter,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=porto+walter%2Cbr
# ID:498 OWM info for andros town,bs
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=andros+town%2Cbs
# ID:499 OWM info for maragogi,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=maragogi%2Cbr
# ID:500 OWM info for circleville,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=circleville%2Cus

# %%
weather_df = weather_df.dropna()
weather_df = weather_df.sample(500) #resample so that n=500
print(weather_df.shape)
weather_df.head()
# Out:
# (500, 9)
#                  city country_code  Latitude  Longitude  Temperature  \
# 286          bucovice           cz     49.15      17.00         7.00
# 360  bocana de paiwas           ni     12.79     -85.12        29.62
# 744          ust-maya           ru     60.42     134.54        -7.09
# 358           sorland           no     67.67      12.69         1.00
# 149            qarqin           af     37.41      66.03        14.72
#
#      Wind speed  Humidity  Cloudiness  Wind_speed
# 286        4.60      42.0         0.0        4.10
# 360        3.03      56.0        12.0        3.03
# 744        2.63      80.0        88.0        2.63
# 358        3.10      86.0        75.0        3.10
# 149        3.83      70.0        80.0        3.83

# %%
plt.hist(weather_df.Latitude) #To observe the distribution of the latitudinal variable
# Out:
# (array([ 7., 21., 43., 54., 58., 52., 66., 88., 75., 36.]),
#  array([-54.81, -42.05, -29.29, -16.53,  -3.77,   8.99,  21.75,  34.51,
#          47.27,  60.03,  72.79]),
#  <a list of 10 Patch objects>)

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import cufflinks as cf
from plotly.graph_objs import Scatter, Figure, Layout

# %%
cf.set_config_file(offline=False, world_readable=True, theme='pearl')

df = pd.DataFrame({'Latitude': weather_df.Latitude,
                   'Temperature (°C)': weather_df.Temperature,
                   'Wind speed (mph)': weather_df.Wind_speed,
                  'Humidity (%)': weather_df.Humidity,
                   'Cloudiness (%)': weather_df.Cloudiness
                  })
df.head(2)

df.iplot(kind='histogram', subplots=True, shape=(5, 1), filename='weatherpy/histogram-subplots')
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-76-b4d18d31677c> in <module>()
#       9 df.head(2)
#      10
# ---> 11 df.iplot(kind='histogram', subplots=True, shape=(5, 1), filename='weatherpy/histogram-subplots')
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, data, layout, filename, sharing, kind, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1056                 return py.plot(figure,sharing=sharing,filename=filename,validate=validate,auto_open=False)
#    1057         else:
# -> 1058                 return iplot(figure,sharing=sharing,filename=filename,validate=validate,online=online)
#    1059
#    1060
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\cufflinks\plotlytools.py in iplot(data_or_figure, validate, sharing, filename, online, **kwargs)
#    1200                         filename='Plotly Playground {0}'.format(time.strftime("%Y-%m-%d %H:%M:%S"))
#    1201 		return py.iplot(data_or_figure,validate=validate,sharing=sharing,
# -> 1202 						filename=filename)
#    1203
#    1204 def _ta_figure(self,**kwargs):
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\plotly\plotly\plotly.py in iplot(figure_or_data, **plot_options)
#     138     if 'auto_open' not in plot_options:
#     139         plot_options['auto_open'] = False
# --> 140     url = plot(figure_or_data, **plot_options)
#     141
#     142     if isinstance(figure_or_data, dict):
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\plotly\plotly\plotly.py in plot(figure_or_data, validate, **plot_options)
#     231     data = fig.get('data', [])
#     232     plot_options['layout'] = fig.get('layout', {})
# --> 233     response = v1.clientresp(data, **plot_options)
#     234
#     235     # Check if the url needs a secret key
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\plotly\api\v1\clientresp.py in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\plotly\api\v1\utils.py in request(method, url, **kwargs)
#      84         content = response.content if response else 'No content'
#      85         raise exceptions.PlotlyRequestError(message, status_code, content)
# ---> 86     validate_response(response)
#      87     return response
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\plotly\api\v1\utils.py in validate_response(response)
#      36         message = content if content else 'No Content'
#      37
# ---> 38     raise exceptions.PlotlyRequestError(message, status_code, content)
#      39
#      40
#
# PlotlyRequestError: Hi there! Free users cannot create folders.
#
# To save this file on Plotly, please remove the folder in your filename path.
#
# If you would like to create folders and save files in them, please upgrade your account at: https://goo.gl/NrPpg6

# %%
iplot([{"x": [1, 2, 3], "y": [3, 1, 6]}])
