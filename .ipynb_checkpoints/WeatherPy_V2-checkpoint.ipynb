# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import json
import pandas as pd
from pprint import pprint
import openweathermapy.core as owm
import seaborn as sns

# %%
import numpy as np

np_lat = np.arange(-90,90,10)
np_lng = np.arange(-180,180,18)
# coordinates = (np_lat,np_lng) #Better keeping lat/lng in separate columns

import random

rnd_lat = random.choice(np_lat)
rnd_lng = random.choice(np_lng)
# rnd_coordinates = random.choice(coordinates) #Better keeping lat/lng in separate columns

from citipy import citipy

weather_df = pd.DataFrame()
weather_df['rnd_lat']=""
weather_df['rnd_lng']=""

for x in np_lat:
    for y in np_lng:
        x_values = list(np.arange(-90,90,0.01))
        y_values = list(np.arange(-180,180,0.01))
        lats = random.sample(x_values,17999) #why 17999 instead of 500? Because of duplicates..
        lons = random.sample(y_values,17999) #..stemming from the geocoords from citipy
                                            #and that's the maximum number of samples I can input
                                            #given the latitude parameters (180/0.01 = 18000)
                                            #Also I believe a larger sampling size to be better to
                                            #increase the random distribution of values.
        
weather_df = weather_df.append(pd.DataFrame.from_dict({"rnd_lat":lats,
                                       "rnd_lng":lons}))

weather_df = weather_df.reset_index(drop=True)



weather_df['city']=""
weather_df['country_code']=""

for index,row in weather_df.iterrows():
        weather_df_city = citipy.nearest_city(row["rnd_lat"], row["rnd_lng"])
        weather_df.set_value(index,"city",weather_df_city.city_name)
        weather_df.set_value(index,"country_code",weather_df_city.country_code)
        
weather_df=weather_df.drop(['rnd_lat', 'rnd_lng'],axis=1) #geo coord don't correspond to cities

weather_df=weather_df.drop_duplicates() #hmmm, some coords might yield similar cities....
print("Sampling size (from n = 17,999) after dumping duplicates: n=" + str(len(weather_df)))

weather_df = weather_df.sample(800) #resample so that n=800 (why? because some cities will may lack
                                    # data for certain attributes, so we'll re-sample once data has
                                    # dropped any rows with NULL values for any attributes)
weather_df = weather_df.reset_index(drop=True) #Remove index pre-resampling

print(weather_df.head())

print("Confirm n = 800: " + str(weather_df.shape))
# Out:
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:42: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:43: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Sampling size (from n = 17,999) after dumping duplicates: n=3412
#           city country_code
# 0         cham           de
# 1  southbridge           nz
# 2        goure           ne
# 3     asbestos           ca
# 4   moses lake           us
# Confirm n = 800: (800, 2)

# %%
from config2 import api_key 

    # Set parameters to pass in query URL
units = "metric" 
params = {
    "appid": api_key,
    "units": "metric",
}

    # Set counter for request iteration for each city
counter = 0

    # Set Request Loop
for index, row in weather_df.iterrows():
    params["q"] =f'{row["city"]},{row["country_code"]}' #Set location params: city, country_code
    target_url = 'http://api.openweathermap.org/data/2.5/weather?' #i.e. OWM's base API url

    counter += 1 # add to the index count for each iterations
#     print("Now retrieving city # " + str(counter)) #making sure the counter iteration is working
    
    city_owm = requests.get(target_url, params=params)
    print("ID:"+ str(counter) + " " + "OWM info for " + str( params["q"]))
    print(city_owm.url) #making sure the request iterations are working for each location.
    
    city_owm  = city_owm.json()
    
    #Pull attributes of interest from OWM request
    weather_df.set_value(index,"Latitude",city_owm.get("coord",{}).get("lat"))
    weather_df.set_value(index,"Longitude",city_owm.get("coord",{}).get("lon"))
    weather_df.set_value(index,"Temperature",city_owm.get("main",{}).get("temp_max"))
    weather_df.set_value(index,"Wind_speed",city_owm.get("wind",{}).get("speed"))
    weather_df.set_value(index,"Humidity",city_owm.get("main",{}).get("humidity"))
    weather_df.set_value(index,"Cloudiness",city_owm.get("clouds",{}).get("all"))
# Out:
# ID:1 OWM info for bowen,au
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=bowen%2Cau
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:30: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:31: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:32: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:33: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# ID:2 OWM info for zaraza,ve
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=zaraza%2Cve
# ID:3 OWM info for muscat,om
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=muscat%2Com
# ID:4 OWM info for mayo,ca
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=mayo%2Cca
# ID:5 OWM info for richards bay,za
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=richards+bay%2Cza
# ID:6 OWM info for binzhou,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=binzhou%2Ccn
# ID:7 OWM info for capela,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=capela%2Cbr
# ID:8 OWM info for bulawayo,zw
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=bulawayo%2Czw
# ID:9 OWM info for jalu,ly
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=jalu%2Cly
# ID:10 OWM info for tuggurt,dz
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=tuggurt%2Cdz
# ID:11 OWM info for bikaner,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=bikaner%2Cin
# ID:12 OWM info for saravan,la
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=saravan%2Cla
# ID:13 OWM info for tutoia,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=tutoia%2Cbr
# ID:14 OWM info for cambara,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=cambara%2Cbr
# ID:15 OWM info for belyy yar,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=belyy+yar%2Cru
# ID:16 OWM info for bac giang,vn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=bac+giang%2Cvn
# ID:17 OWM info for pouembout,nc
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=pouembout%2Cnc
# ID:18 OWM info for iznoski,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=iznoski%2Cru
# ID:19 OWM info for jumla,np
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=jumla%2Cnp
# ID:20 OWM info for shelopugino,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=shelopugino%2Cru
# ID:21 OWM info for izhma,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=izhma%2Cru
# ID:22 OWM info for opunake,nz
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=opunake%2Cnz
# ID:23 OWM info for south lake tahoe,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=south+lake+tahoe%2Cus
# ID:24 OWM info for kinchil,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kinchil%2Cmx
# ID:25 OWM info for pilikwe,bw
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=pilikwe%2Cbw
# ID:26 OWM info for gariaband,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=gariaband%2Cin
# ID:27 OWM info for gazanjyk,tm
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=gazanjyk%2Ctm
# ID:28 OWM info for san juan,ar
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=san+juan%2Car
# ID:29 OWM info for baisha,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=baisha%2Ccn
# ID:30 OWM info for bealanana,mg
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=bealanana%2Cmg
# ID:31 OWM info for mahibadhoo,mv
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=constitucion%2Ccl
# ID:81 OWM info for grenaa,dk
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=grenaa%2Cdk
# ID:82 OWM info for manakara,mg
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=manakara%2Cmg
# ID:83 OWM info for pagman,af
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=pagman%2Caf
# ID:84 OWM info for manta,ec
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=manta%2Cec
# ID:85 OWM info for aitape,pg
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=aitape%2Cpg
# ID:86 OWM info for faanui,pf
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=faanui%2Cpf
# ID:87 OWM info for langham,ca
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=langham%2Cca
# ID:88 OWM info for dalby,au
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=dalby%2Cau
# ID:89 OWM info for valparaiso,cl
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=valparaiso%2Ccl
# ID:90 OWM info for wellington,au
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=wellington%2Cau
# ID:91 OWM info for la ronge,ca
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=la+ronge%2Cca
# ID:92 OWM info for kunya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kunya%2Cru
# ID:93 OWM info for san blas,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=san+blas%2Cmx
# ID:94 OWM info for vallenar,cl
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=vallenar%2Ccl
# ID:95 OWM info for ondorhaan,mn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ondorhaan%2Cmn
# ID:96 OWM info for sibu,my
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=sibu%2Cmy
# ID:97 OWM info for itambe,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=itambe%2Cbr
# ID:98 OWM info for truro,gb
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=truro%2Cgb
# ID:99 OWM info for benalla,au
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=benalla%2Cau
# ID:100 OWM info for along,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=along%2Cin
# ID:101 OWM info for vostok,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=vostok%2Cru
# ID:102 OWM info for atocha,bo
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=atocha%2Cbo
# ID:103 OWM info for estremoz,pt
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=estremoz%2Cpt
# ID:104 OWM info for tupik,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=tupik%2Cru
# ID:105 OWM info for ola,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ola%2Cru
# ID:106 OWM info for bac lieu,vn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=bac+lieu%2Cvn
# ID:107 OWM info for asosa,et
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=asosa%2Cet
# ID:108 OWM info for kebumen,id
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kebumen%2Cid
# ID:109 OWM info for lashio,mm
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=lashio%2Cmm
# ID:110 OWM info for kharitonovo,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kharitonovo%2Cru
# ID:111 OWM info for kloulklubed,pw
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kloulklubed%2Cpw
# ID:112 OWM info for tawzar,tn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=tawzar%2Ctn
# ID:113 OWM info for aquiraz,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=aquiraz%2Cbr
# ID:114 OWM info for bayeux,fr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=bayeux%2Cfr
# ID:115 OWM info for chokurdakh,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=chokurdakh%2Cru
# ID:116 OWM info for krishnarajpet,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=krishnarajpet%2Cin
# ID:117 OWM info for iquitos,pe
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=iquitos%2Cpe
# ID:118 OWM info for karlskrona,se
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=karlskrona%2Cse
# ID:119 OWM info for savonlinna,fi
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=savonlinna%2Cfi
# ID:120 OWM info for san andres,co
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=san+andres%2Cco
# ID:121 OWM info for vila praia de ancora,pt
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=vila+praia+de+ancora%2Cpt
# ID:122 OWM info for sembakung,id
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=sembakung%2Cid
# ID:123 OWM info for souillac,mu
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=souillac%2Cmu
# ID:124 OWM info for kurilsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kurilsk%2Cru
# ID:125 OWM info for guanica,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=guanica%2Cus
# ID:126 OWM info for rio cuarto,ar
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=rio+cuarto%2Car
# ID:127 OWM info for beysehir,tr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=beysehir%2Ctr
# ID:128 OWM info for gerash,ir
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=gerash%2Cir
# ID:129 OWM info for beaverlodge,ca
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=beaverlodge%2Cca
# ID:130 OWM info for durusu,tr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=maniitsoq%2Cgl
# ID:230 OWM info for zheleznodorozhnyy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=zheleznodorozhnyy%2Cru
# ID:231 OWM info for zatoka,ua
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=zatoka%2Cua
# ID:232 OWM info for papara,pf
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=papara%2Cpf
# ID:233 OWM info for pangoa,pe
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=pangoa%2Cpe
# ID:234 OWM info for kodyma,ua
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kodyma%2Cua
# ID:235 OWM info for almeirim,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=almeirim%2Cbr
# ID:236 OWM info for maamba,zm
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=maamba%2Czm
# ID:237 OWM info for banamba,ml
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=banamba%2Cml
# ID:238 OWM info for cubuk,tr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=cubuk%2Ctr
# ID:239 OWM info for nelson,ca
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=nelson%2Cca
# ID:240 OWM info for aksha,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=aksha%2Cru
# ID:241 OWM info for ixtapa,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ixtapa%2Cmx
# ID:242 OWM info for gerede,tr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=gerede%2Ctr
# ID:243 OWM info for kokoda,pg
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kokoda%2Cpg
# ID:244 OWM info for thaton,mm
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=thaton%2Cmm
# ID:245 OWM info for baoding,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=baoding%2Ccn
# ID:246 OWM info for smidovich,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=smidovich%2Cru
# ID:247 OWM info for nguiu,au
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=nguiu%2Cau
# ID:248 OWM info for ures,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ures%2Cmx
# ID:249 OWM info for villanueva de la serena,es
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=villanueva+de+la+serena%2Ces
# ID:250 OWM info for neiafu,to
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=neiafu%2Cto
# ID:251 OWM info for faya,td
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=faya%2Ctd
# ID:252 OWM info for vienne,fr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=vienne%2Cfr
# ID:253 OWM info for spirit river,ca
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=spirit+river%2Cca
# ID:254 OWM info for antofagasta,cl
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=antofagasta%2Ccl
# ID:255 OWM info for ostrovskoye,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ostrovskoye%2Cru
# ID:256 OWM info for sakaiminato,jp
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=sakaiminato%2Cjp
# ID:257 OWM info for changchun,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=changchun%2Ccn
# ID:258 OWM info for aktash,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=aktash%2Cru
# ID:259 OWM info for petatlan,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=petatlan%2Cmx
# ID:260 OWM info for port hardy,ca
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=port+hardy%2Cca
# ID:261 OWM info for ribeira grande,pt
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ribeira+grande%2Cpt
# ID:262 OWM info for kuruman,za
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kuruman%2Cza
# ID:263 OWM info for kassiopi,gr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kassiopi%2Cgr
# ID:264 OWM info for winneba,gh
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=winneba%2Cgh
# ID:265 OWM info for kamaishi,jp
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kamaishi%2Cjp
# ID:266 OWM info for teya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=teya%2Cru
# ID:267 OWM info for boca do acre,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=boca+do+acre%2Cbr
# ID:268 OWM info for parvatsar,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=parvatsar%2Cin
# ID:269 OWM info for mizdah,ly
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=mizdah%2Cly
# ID:270 OWM info for cockburn town,bs
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=cockburn+town%2Cbs
# ID:271 OWM info for raton,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=raton%2Cus
# ID:272 OWM info for zunheboto,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=zunheboto%2Cin
# ID:273 OWM info for kansanshi,zm
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kansanshi%2Czm
# ID:274 OWM info for juneau,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=juneau%2Cus
# ID:275 OWM info for honiara,sb
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=honiara%2Csb
# ID:276 OWM info for faranah,gn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=faranah%2Cgn
# ID:277 OWM info for nirgua,ve
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=nirgua%2Cve
# ID:278 OWM info for pareora,nz
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=pareora%2Cnz
# ID:279 OWM info for boguchany,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=boguchany%2Cru
# ID:280 OWM info for ankang,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ankang%2Ccn
# ID:281 OWM info for kati,ml
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kati%2Cml
# ID:282 OWM info for naron,es
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=naron%2Ces
# ID:283 OWM info for tonantins,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=tonantins%2Cbr
# ID:284 OWM info for gornopravdinsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=gornopravdinsk%2Cru
# ID:285 OWM info for taseyevo,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=taseyevo%2Cru
# ID:286 OWM info for zastron,za
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=zastron%2Cza
# ID:287 OWM info for kasempa,zm
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kasempa%2Czm
# ID:288 OWM info for gurupa,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=gurupa%2Cbr
# ID:289 OWM info for santa elena,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=santa+elena%2Cmx
# ID:290 OWM info for takab,ir
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=takab%2Cir
# ID:291 OWM info for san quintin,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=san+quintin%2Cmx
# ID:292 OWM info for avesta,se
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=avesta%2Cse
# ID:293 OWM info for betare oya,cm
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=betare+oya%2Ccm
# ID:294 OWM info for ambovombe,mg
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ambovombe%2Cmg
# ID:295 OWM info for novyy urgal,ru
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=novyy+urgal%2Cru
# ID:296 OWM info for zhaotong,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=zhaotong%2Ccn
# ID:297 OWM info for quatre cocos,mu
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=quatre+cocos%2Cmu
# ID:298 OWM info for blantyre,mw
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=blantyre%2Cmw
# ID:299 OWM info for goure,ne
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=goure%2Cne
# ID:300 OWM info for altay,cn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=altay%2Ccn
# ID:301 OWM info for ngawen,id
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ngawen%2Cid
# ID:302 OWM info for santiago de cao,pe
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=santiago+de+cao%2Cpe
# ID:303 OWM info for fort saint james,ca
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=fort+saint+james%2Cca
# ID:304 OWM info for porto novo,cv
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=porto+novo%2Ccv
# ID:305 OWM info for sitio novo do tocantins,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=sitio+novo+do+tocantins%2Cbr
# ID:306 OWM info for kesinga,in
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kesinga%2Cin
# ID:307 OWM info for ambilobe,mg
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=ambilobe%2Cmg
# ID:308 OWM info for hermosa beach,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=hermosa+beach%2Cus
# ID:309 OWM info for hasaki,jp
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=hasaki%2Cjp
# ID:310 OWM info for el fuerte,mx
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=el+fuerte%2Cmx
# ID:311 OWM info for qeshm,ir
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=qeshm%2Cir
# ID:312 OWM info for havoysund,no
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=havoysund%2Cno
# ID:313 OWM info for mbanza-ngungu,cd
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=mbanza-ngungu%2Ccd
# ID:314 OWM info for labuhan,id
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=labuhan%2Cid
# ID:315 OWM info for cermik,tr
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=cermik%2Ctr
# ID:316 OWM info for avarua,ck
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=avarua%2Cck
# ID:317 OWM info for georgetown,gy
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=georgetown%2Cgy
# ID:318 OWM info for mwanza,mw
# ...
# ID:393 OWM info for the pas,ca
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=the+pas%2Cca
# ID:394 OWM info for kabo,cf
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kabo%2Ccf
# ID:395 OWM info for barrow,us
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=barrow%2Cus
# ID:396 OWM info for kerewan,gm
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kerewan%2Cgm
# ID:397 OWM info for san francisco de becerra,hn
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=san+francisco+de+becerra%2Chn
# ID:398 OWM info for vanderhoof,ca
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=vanderhoof%2Cca
# ID:399 OWM info for guaimaro,cu
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=guaimaro%2Ccu
# ID:400 OWM info for correntina,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=correntina%2Cbr
# ID:401 OWM info for bousse,bf
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=kpalime%2Ctg
# ID:500 OWM info for urucara,br
# http://api.openweathermap.org/data/2.5/weather?appid=9f87482612efa739e32c116922d4daac&units=metric&q=urucara%2Cbr

# %%
weather_df = weather_df.dropna()
# weather_df = weather_df.sample(500) #resample so that n=500
print(weather_df.shape)
weather_df.head()


# import csv
weather_df.to_csv("owm_sample.csv",index=False)

# Save to df
weather_csv = "owm_sample.csv"
weather_df = pd.read_csv(weather_csv)
# Out:
# (455, 8)

# %%
weather_df.to_pickle("weather_df.pkl")
weather_df=pd.read_pickle("weather_df.pkl")
print(weather_df.columns)
print(weather_df.shape)
weather_df.head()

weather_df_lat = weather_df['Latitude']
weather_df_temp = weather_df['Temperature']
weather_df_hum = weather_df.Humidity
weather_df_clo = weather_df.Cloudiness
weather_df_wind = weather_df.Wind_speed

df = pd.DataFrame({'Latitude': weather_df.Latitude,
                   'Temperature (°C)': weather_df.Temperature,
                   'Wind speed (mph)': weather_df.Wind_speed,
                  'Humidity (%)': weather_df.Humidity,
                   'Cloudiness (%)': weather_df.Cloudiness
                  })

df.head()
# Out:
# Index(['city', 'country_code', 'Latitude', 'Longitude', 'Temperature',
#        'Wind_speed', 'Humidity', 'Cloudiness'],
#       dtype='object')
# (455, 8)
#    Cloudiness (%)  Humidity (%)  Latitude  Temperature (°C)  Wind speed (mph)
# 0            44.0          78.0    -20.01             25.00              4.60
# 1             8.0          62.0      9.35             28.19              5.26
# 2             0.0          41.0     23.60             25.00              2.60
# 3            90.0          36.0     63.59              7.00              1.00
# 4            20.0          96.0    -28.77             18.41              1.61

# %%
# Histogram of the distribution of sampled Latitudes
    # Plotly tutorial: https://plot.ly/python/histograms/

print(weather_df_lat.describe())
    
import plotly.plotly as py
import plotly.graph_objs as go

import numpy as np

data = [go.Histogram(y=weather_df_lat)]
#######
    # Reference: https://plot.ly/python/shapes/

layout = {
    'xaxis': {
        'range': [0, 40]
    },
    'yaxis': {
        'range': [-50, 90]
    },
    'shapes': [

# Line Horizontal
        # Equator
        {
            'type': 'line',
            'x0': 0,
            'y0': 0,
            'x1': 40,
            'y1': 0,
            'line': {
                'color': 'rgb(220, 20, 60)',
                'width': 2
            },
        },
    ]}

fig = {
    'data': data,
    'layout': layout,
}
####
py.iplot(fig, filename='horizontal histogram')
# Out:
# count    455.000000
# mean      21.457538
# std       28.927899
# min      -44.490000
# 25%       -2.650000
# 50%       26.020000
# 75%       45.220000
# max       78.220000
# Name: Latitude, dtype: float64
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~HP-Nunes/9.embed" height="525px" width="100%"></iframe>

# %%
# Histogram of the distribution of sampled Temperatures

print(weather_df_temp.describe())

import plotly.plotly as py
import plotly.graph_objs as go

import numpy as np

data = [go.Histogram(x=weather_df_temp)]

py.iplot(data, filename='basic histogram')
# Out:
# count    455.000000
# mean      16.292154
# std       10.220038
# min      -21.320000
# 25%       10.000000
# 50%       18.190000
# 75%       24.685000
# max       38.000000
# Name: Temperature, dtype: float64
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~HP-Nunes/11.embed" height="525px" width="100%"></iframe>

# %%
# Import packages for Regression Plot

import plotly.plotly as py
import plotly.graph_objs as go

import numpy as np
from sklearn import datasets, linear_model

# %%
# Temperature (C) vs. Latitude

weather_df_temp=weather_df_temp.reshape(-1, 1)
weather_df_lat=weather_df_lat.reshape(-1, 1)

# Plotly regression tutorial : https://plot.ly/scikit-learn/plot-ols/

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(weather_df_lat, weather_df_temp)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % np.mean((regr.predict(weather_df_lat) - weather_df_temp) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(weather_df_lat, weather_df_temp))

####

def data_to_plotly(x):
    k = []
    
    for i in range(0, len(x)):
        k.append(x[i][0])
        
    return k
####
p1 = go.Scatter(x=data_to_plotly(weather_df_lat), 
                y=weather_df_temp, 
                mode='markers',
                marker=dict(color='black')
               )

p2 = go.Scatter(x=data_to_plotly(weather_df_lat), 
                y=regr.predict(weather_df_lat),
                mode='lines',
                line=dict(color='blue', width=3)
                )

layout = go.Layout(xaxis=dict(ticks='', showticklabels=False,
                              zeroline=False),
                   yaxis=dict(ticks='', showticklabels=False,
                              zeroline=False),
                   showlegend=False, hovermode='closest')

fig = go.Figure(data=[p1, p2], layout=layout)

py.iplot(fig)
# Out:
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:3: FutureWarning:
#
# reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# Coefficients:
#  [[-0.22413937]]
# Mean squared error: 62.27
# Variance score: 0.40
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~HP-Nunes/25.embed" height="525px" width="100%"></iframe>

# %%
# Humidity (%) vs. Latitude

print(weather_df_hum.describe())

weather_df_hum=weather_df_hum.reshape(-1, 1)
weather_df_lat=weather_df_lat.reshape(-1, 1)

# Plotly regression tutorial : https://plot.ly/scikit-learn/plot-ols/

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(weather_df_lat, weather_df_hum)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % np.mean((regr.predict(weather_df_lat) - weather_df_hum) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(weather_df_lat, weather_df_hum))

####
def data_to_plotly(x):
    k = []
    
    for i in range(0, len(x)):
        k.append(x[i][0])
        
    return k

####
p1 = go.Scatter(x=data_to_plotly(weather_df_lat), 
                y=weather_df_hum, 
                mode='markers',
                marker=dict(color='black')
               )

p2 = go.Scatter(x=data_to_plotly(weather_df_lat), 
                y=regr.predict(weather_df_lat),
                mode='lines',
                line=dict(color='blue', width=3)
                )

layout = go.Layout(xaxis=dict(ticks='', showticklabels=False,
                              zeroline=False),
                   yaxis=dict(ticks='', showticklabels=False,
                              zeroline=False),
                   showlegend=False, hovermode='closest')

fig = go.Figure(data=[p1, p2], layout=layout)

py.iplot(fig)
# Out:
# count    455.000000
# mean      73.718681
# std       21.444734
# min        7.000000
# 25%       60.000000
# 50%       78.000000
# 75%       92.000000
# max      100.000000
# Name: Humidity, dtype: float64
# Coefficients:
#  [[-0.18456233]]
# Mean squared error: 430.42
# Variance score: 0.06
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:5: FutureWarning:
#
# reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:6: FutureWarning:
#
# reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~HP-Nunes/27.embed" height="525px" width="100%"></iframe>

# %%
# Cloudiness (%) vs. Latitude

print(weather_df_clo.describe())

weather_df_clo=weather_df_clo.reshape(-1, 1)
weather_df_lat=weather_df_lat.reshape(-1, 1)

# Plotly regression tutorial : https://plot.ly/scikit-learn/plot-ols/

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(weather_df_lat, weather_df_clo)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % np.mean((regr.predict(weather_df_lat) - weather_df_clo) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(weather_df_lat, weather_df_clo))

####
def data_to_plotly(x):
    k = []
    
    for i in range(0, len(x)):
        k.append(x[i][0])
        
    return k

####
p1 = go.Scatter(x=data_to_plotly(weather_df_lat), 
                y=weather_df_clo, 
                mode='markers',
                marker=dict(color='black')
               )

p2 = go.Scatter(x=data_to_plotly(weather_df_lat), 
                y=regr.predict(weather_df_lat),
                mode='lines',
                line=dict(color='blue', width=3)
                )

layout = go.Layout(xaxis=dict(ticks='', showticklabels=False,
                              zeroline=False),
                   yaxis=dict(ticks='', showticklabels=False,
                              zeroline=False),
                   showlegend=False, hovermode='closest')

fig = go.Figure(data=[p1, p2], layout=layout)

py.iplot(fig)
# Out:
# count    455.000000
# mean      35.492308
# std       34.979343
# min        0.000000
# 25%        0.000000
# 50%       24.000000
# 75%       75.000000
# max      100.000000
# Name: Cloudiness, dtype: float64
# Coefficients:
#  [[0.13110055]]
# Mean squared error: 1206.51
# Variance score: 0.01
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:5: FutureWarning:
#
# reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~HP-Nunes/29.embed" height="525px" width="100%"></iframe>

# %%
# Wind Speed (mph) vs. Latitude

print(weather_df_wind.describe())

weather_df_wind=weather_df_wind.reshape(-1, 1)
weather_df_lat=weather_df_lat.reshape(-1, 1)

# Plotly regression tutorial : https://plot.ly/scikit-learn/plot-ols/

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(weather_df_lat, weather_df_wind)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % np.mean((regr.predict(weather_df_lat) - weather_df_wind) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(weather_df_lat, weather_df_wind))

####
def data_to_plotly(x):
    k = []
    
    for i in range(0, len(x)):
        k.append(x[i][0])
        
    return k

####
p1 = go.Scatter(x=data_to_plotly(weather_df_lat), 
                y=weather_df_wind, 
                mode='markers',
                marker=dict(color='black')
               )

p2 = go.Scatter(x=data_to_plotly(weather_df_lat), 
                y=regr.predict(weather_df_lat),
                mode='lines',
                line=dict(color='blue', width=3)
                )

layout = go.Layout(xaxis=dict(ticks='', showticklabels=False,
                              zeroline=False),
                   yaxis=dict(ticks='', showticklabels=False,
                              zeroline=False),
                   showlegend=False, hovermode='closest')

fig = go.Figure(data=[p1, p2], layout=layout)

py.iplot(fig)
# Out:
# count    455.000000
# mean       3.079714
# std        2.167310
# min        0.260000
# 25%        1.500000
# 50%        2.510000
# 75%        4.100000
# max       12.900000
# Name: Wind_speed, dtype: float64
# Coefficients:
#  [[0.0175796]]
# Mean squared error: 4.43
# Variance score: 0.06
# C:\Users\White Base\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:5: FutureWarning:
#
# reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~HP-Nunes/31.embed" height="525px" width="100%"></iframe>
